# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
conn = sqlite3.connect('im.db')

pd.read_sql("""SELECT *
            FROM sqlite_master""",conn)
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %% [markdown]
# # Let's view the various tables

# %% [markdown]
# Let's start with the movie_basics table

# %%
movie_basics = pd.read_sql("""
SELECT *
                            FROM movie_basics""",conn)
movie_basics.isna().sum()

len(movie_basics)
# Out:
# 146144

# %%
#

# %% [markdown]
# The director's table

# %%
directors = pd.read_sql("""
SELECT *
                        FROM directors""",conn)
directors.isna().sum()
# Out:
# movie_id     0
# person_id    0
# dtype: int64

# %% [markdown]
# Known for table

# %%
known_for = pd.read_sql("""
SELECT * FROM known_for""",conn)
known_for.isna().sum()
# Out:
# person_id    0
# movie_id     0
# dtype: int64

# %% [markdown]
# Movie AKAs

# %%
movie_akas = pd.read_sql("""SELECT * FROM movie_akas""",conn)
movie_akas.isna().sum()
# Out:
# movie_id                  0
# ordering                  0
# title                     0
# region                53293
# language             289988
# types                163256
# attributes           316778
# is_original_title        25
# dtype: int64

# %% [markdown]
# Movie ratings

# %%
movie_ratings = pd.read_sql("""SELECT * FROM movie_ratings""",conn)
movie_ratings.isna().sum()
# Out:
# movie_id         0
# averagerating    0
# numvotes         0
# dtype: int64

# %% [markdown]
# Persons table

# %%
persons = pd.read_sql("""SELECT * FROM persons""",conn)
persons.isna().sum()
# Out:
# person_id                  0
# primary_name               0
# birth_year            523912
# death_year            599865
# primary_profession     51340
# dtype: int64

# %% [markdown]
# Principals table

# %%
principals = pd.read_sql("""SELECT * FROM principals""",conn)
principals.isna().sum()
# Out:
# movie_id           0
# ordering           0
# person_id          0
# category           0
# job           850502
# characters    634826
# dtype: int64

# %% [markdown]
# Writers table

# %%
writers = pd.read_sql("""SELECT * FROM writers""",conn)
writers.isna().sum()
# Out:
# movie_id     0
# person_id    0
# dtype: int64

# %% [markdown]
# ## Let's create one merged dataset to conduct Further analysis on.

# %% [markdown]
# We shall merge the movie_basics and movie ratings tables.

# %%
moviename_ratings_df = pd.merge(left=movie_basics, right=movie_ratings, how='left', left_on='movie_id', right_on='movie_id')
moviename_ratings_df.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0      77.0
# 1        2019            114.0       Biography,Drama            7.2      43.0
# 2        2018            122.0                 Drama            6.9    4517.0
# 3        2018              NaN          Comedy,Drama            6.1      13.0
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5     119.0

# %% [markdown]
# We shall merge the moviename_ratings to the directors as we are interested in working with specific directors.

# %%
mr_directors_df = pd.merge(left=moviename_ratings_df, right=directors, how='left', left_on='movie_id', right_on='movie_id')
mr_directors_df.head()
# Out:
#     movie_id                    primary_title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0063540                        Sunghursh        Sunghursh        2013
# 2  tt0063540                        Sunghursh        Sunghursh        2013
# 3  tt0063540                        Sunghursh        Sunghursh        2013
# 4  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes              genres  averagerating  numvotes  person_id
# 0            175.0  Action,Crime,Drama            7.0      77.0  nm0712540
# 1            175.0  Action,Crime,Drama            7.0      77.0  nm0712540
# 2            175.0  Action,Crime,Drama            7.0      77.0  nm0712540
# 3            175.0  Action,Crime,Drama            7.0      77.0  nm0712540
# 4            114.0     Biography,Drama            7.2      43.0  nm0002411

# %% [markdown]
# We shall merge the mr_directors with persons table to get the names.

# %%
movie_dir_df =pd.merge(left=mr_directors_df, right=persons, how='left', left_on='person_id', right_on='person_id')
movie_dir_df.head()
# Out:
#     movie_id                    primary_title   original_title  start_year  \
# 0  tt0063540                        Sunghursh        Sunghursh        2013
# 1  tt0063540                        Sunghursh        Sunghursh        2013
# 2  tt0063540                        Sunghursh        Sunghursh        2013
# 3  tt0063540                        Sunghursh        Sunghursh        2013
# 4  tt0066787  One Day Before the Rainy Season  Ashad Ka Ek Din        2019
#
#    runtime_minutes              genres  averagerating  numvotes  person_id  \
# 0            175.0  Action,Crime,Drama            7.0      77.0  nm0712540
# 1            175.0  Action,Crime,Drama            7.0      77.0  nm0712540
# 2            175.0  Action,Crime,Drama            7.0      77.0  nm0712540
# 3            175.0  Action,Crime,Drama            7.0      77.0  nm0712540
# 4            114.0     Biography,Drama            7.2      43.0  nm0002411
#
#           primary_name  birth_year  death_year        primary_profession
# 0  Harnam Singh Rawail      1921.0      2004.0  director,writer,producer
# 1  Harnam Singh Rawail      1921.0      2004.0  director,writer,producer
# 2  Harnam Singh Rawail      1921.0      2004.0  director,writer,producer
# 3  Harnam Singh Rawail      1921.0      2004.0  director,writer,producer
# 4            Mani Kaul      1944.0      2011.0     director,writer,actor

# %% [markdown]
# We shall rename the data frame to final for ease of use.

# %%
final_df = movie_dir_df

# %% [markdown]
# We shall now proceed to drop unnecessary columns.

# %%
final_df.isna().sum()
# Out:
# movie_id                   0
# primary_title              0
# original_title            22
# start_year                 0
# runtime_minutes        55767
# genres                  8790
# averagerating         114760
# numvotes              114760
# person_id               5727
# primary_name            5730
# birth_year            228293
# death_year            295163
# primary_profession      6714
# dtype: int64

# %% [markdown]
# We shall drop the Original title column .

# %%
final_df.drop(columns=['original_title'], inplace=True)

# %% [markdown]
# We shall drop  primary profession, as well

# %%
final_df.drop(columns=['primary_profession'], inplace=True)

# %% [markdown]
# We shall drop off dead directors as well.

# %%
final_df = final_df[final_df['death_year'].isna()]

# %% [markdown]
# We shall drop the rows with no primary name as we dont have a director for the film.

# %%
final_df = final_df[final_df['primary_name'].notna()]

# %%
len(final_df)
# Out:
# 289433

# %% [markdown]
# We shall work with recent films

# %%
final_df['start_year'].value_counts()
# Out:
# start_year
# 2016    37109
# 2014    36476
# 2017    33304
# 2018    32420
# 2015    31949
# 2013    28721
# 2011    26420
# 2012    25311
# 2010    21597
# 2019    14366
# 2020     1565
# 2021      154
# 2022       29
# 2023        6
# 2025        2
# 2027        2
# 2115        1
# 2024        1
# Name: count, dtype: int64

# %% [markdown]
# We shall keep films from 2010 onwards

# %%
final_df = final_df[final_df['start_year']>=2009]

# %% [markdown]
# We shall drop films with missing genres

# %%
final_df = final_df[final_df['genres'].notna()]

# %% [markdown]
# Check for duplicates

# %%
#check for duplicate values once again

final_df.duplicated().sum()
# Out:
# 124073

# %% [markdown]
# Drop the duplicates

# %%
final_df.drop_duplicates(inplace=True)

# %%
#check for missing values
final_df.isna().sum()
# Out:
# movie_id                0
# primary_title           0
# start_year              0
# runtime_minutes     30729
# genres                  0
# averagerating       74297
# numvotes            74297
# person_id               0
# primary_name            0
# birth_year         126195
# death_year         158835
# dtype: int64

# %% [markdown]
# Let's check the stats for runtimes to decide what value to place in the empty cells

# %%
final_df['runtime_minutes'].describe()
# Out:
# count    128106.000000
# mean         86.721168
# std         224.278154
# min           1.000000
# 25%          70.000000
# 50%          87.000000
# 75%          99.000000
# max       51420.000000
# Name: runtime_minutes, dtype: float64

# %% [markdown]
# # about 90 to 110 minutes
# Movies, too, have been reshaped by their technology, but in different ways than music. Movie length used to be limited to the size of a film reel, which plays about 11 minutes of footage. The standard length of a film is still, to this day, nine reels, or about 90 to 110 minutes long
#
# Source : Vox

# %% [markdown]
# we shall set the missing values for runtime the mean time.

# %%
final_df['runtime_minutes'].fillna(final_df['runtime_minutes'].mean(),inplace=True)

# %%
#check for missing values once again
final_df.isna().sum()
# Out:
# movie_id                0
# primary_title           0
# start_year              0
# runtime_minutes         0
# genres                  0
# averagerating       74297
# numvotes            74297
# person_id               0
# primary_name            0
# birth_year         126195
# death_year         158835
# dtype: int64

# %% [markdown]
# Let's check the stats for average rating

# %%
final_df['averagerating'].describe()
# Out:
# count    84538.000000
# mean         6.339986
# std          1.475908
# min          1.000000
# 25%          5.500000
# 50%          6.500000
# 75%          7.400000
# max         10.000000
# Name: averagerating, dtype: float64

# %% [markdown]
# We shall see the numbers for the ratings to decide if we shall use mean again

# %%
print('Less than 6 : ',(final_df['averagerating']<6).sum())
print('Less than 5 : ',(final_df['averagerating']<5).sum())
print('Less than 4 : ',(final_df['averagerating']<4).sum())
print('Less than 3 : ',(final_df['averagerating']<3).sum())
print('Less than 2 : ',(final_df['averagerating']<2).sum())
# Out:
# Less than 6 :  29792
# Less than 5 :  14125
# Less than 4 :  5969
# Less than 3 :  1971
# Less than 2 :  490

# %%
sns.histplot(final_df['averagerating'])
plt.xlabel('Average rating')
plt.ylabel('Number of films')
# Out:
# Text(0, 0.5, 'Number of films')

# %% [markdown]
# Let's pick out the directors with the highest rating

# %%
director_avg_rating = final_df.groupby('primary_name')['averagerating']>7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 director_avg_rating = final_df.groupby('primary_name')['averagerating']>7
#
# TypeError: '>' not supported between instances of 'SeriesGroupBy' and 'int'

# %%
high_rated_directors = director_avg_rating[director_avg_rating > 7]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[222], line 1
# ----> 1 high_rated_directors = director_avg_rating[director_avg_rating > 7]
#
# TypeError: '>' not supported between instances of 'SeriesGroupBy' and 'int'

# %%
final_df['primary_name'].value_counts().head(20)
# Out:
# primary_name
# Omer Pasha             60
# Larry Rosen            53
# Rajiv Chilaka          49
# Stephan Düfel          47
# Graeme Duane           45
# Claudio Costa          42
# Nayato Fio Nuala       41
# Gérard Courant         41
# Dustin Ferguson        39
# Sergey A.              39
# Jason Impey            37
# Eckhart Schmidt        37
# Tony Newton            35
# Michael Fredianelli    32
# Charlie Minn           29
# Paul T.T. Easter       28
# David DeCoteau         27
# Sam Mason-Bell         27
# Manny Velazquez        27
# William Winckler       27
# Name: count, dtype: int64

# %% [markdown]
# We shall check the average ratings for the various directors and drop those that have missing ratings.

# %%
omer_1_pasha = final_df[final_df['primary_name']=='Omer Pasha']

# %%
omer_1_pasha['averagerating'].isna().sum()
# Out:
# 60

# %% [markdown]
# We shall drop Omer Pasha as he has no ratings.

# %%
final_df = final_df[final_df['primary_name'] != 'Omer Pasha']

# %%
#Let's check for Larry rosen
larry_rosen = final_df[final_df['primary_name']=='Larry Rosen']

# %%
larry_rosen['averagerating'].isna().sum()

# We shall keep larry and use the mean rating to fill in blanks.
# Out:
# 0

# %%
larry_rosen['averagerating'] = larry_rosen['averagerating'].fillna(larry_rosen['averagerating'].mean())
# Out:
# C:\Users\DanielOgando\AppData\Local\Temp\ipykernel_16340\2833201486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   larry_rosen['averagerating'] = larry_rosen['averagerating'].fillna(larry_rosen['averagerating'].mean())

# %%
#we shall do the same for num votes.
larry_rosen['numvotes'] = larry_rosen['numvotes'].fillna(larry_rosen['numvotes'].mean())
# Out:
# C:\Users\DanielOgando\AppData\Local\Temp\ipykernel_16340\2548470637.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   larry_rosen['numvotes'] = larry_rosen['numvotes'].fillna(larry_rosen['numvotes'].mean())

# %%
#Let's check for Rajiv Chilaka
rajiv_chilaka = final_df[final_df['primary_name']=='Rajiv Chilaka']

# %%
#check for missing values
rajiv_chilaka['averagerating'].isna().sum()
# Out:
# 37

# %%
#Let's do the same for rajive replacing missing values with means.
rajiv_chilaka['averagerating'] = rajiv_chilaka['averagerating'].fillna(rajiv_chilaka['averagerating'].mean())
rajiv_chilaka['numvotes'] = rajiv_chilaka['numvotes'].fillna(rajiv_chilaka['numvotes'].mean())
# Out:
# C:\Users\DanielOgando\AppData\Local\Temp\ipykernel_16340\2472311826.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rajiv_chilaka['averagerating'] = rajiv_chilaka['averagerating'].fillna(rajiv_chilaka['averagerating'].mean())
# C:\Users\DanielOgando\AppData\Local\Temp\ipykernel_16340\2472311826.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rajiv_chilaka['numvotes'] = rajiv_chilaka['numvotes'].fillna(rajiv_chilaka['numvotes'].mean())

# %%
#Let's check for Stephan Düfel
stephan_dufel = final_df[final_df['primary_name']=='Stephan Düfel']

# %%
#check for missing values
stephan_dufel.isna().sum()
# Out:
# movie_id            0
# primary_title       0
# start_year          0
# runtime_minutes     0
# genres              0
# averagerating      47
# numvotes           47
# person_id           0
# primary_name        0
# birth_year         47
# death_year         47
# dtype: int64

# %% [markdown]
# We shall drop for Stephan Düfel as he has no ratings or votes.

# %%
final_df = final_df[final_df['primary_name'] != 'Stephan Düfel']

# %%
#let's check for Graeme Duane
final_df[final_df['primary_name']=='i'].isna().sum()
# Out:
# movie_id           0.0
# primary_title      0.0
# start_year         0.0
# runtime_minutes    0.0
# genres             0.0
# averagerating      0.0
# numvotes           0.0
# person_id          0.0
# primary_name       0.0
# birth_year         0.0
# death_year         0.0
# dtype: float64

# %%
omer_1_pasha.head()
# Out:
#          movie_id                                      primary_title  \
# 142004  tt3828760  Omer Pasha Music Videos (American Television E...
# 142413  tt3839030    Omer Pasha Music Videos: Vancouver Gala Edition
# 143149  tt3861384                         The Soul of Cole (Musical)
# 143428  tt3868686        Omer Pasha Music Videos (Bollywood Edition)
# 143877  tt3885692             The Cal Crew (Caucasian Love Returned)
#
#         start_year  runtime_minutes                       genres  \
# 142004        2014             90.0       Music,Musical,Thriller
# 142413        2014            138.0        Music,Musical,Mystery
# 143149        2013            149.0  Adventure,Animation,Musical
# 143428        2014             90.0      Horror,Romance,Thriller
# 143877        2013             84.0        Music,Musical,Mystery
#
#         averagerating  numvotes  person_id primary_name  birth_year  \
# 142004            NaN       NaN  nm3266654   Omer Pasha         NaN
# 142413            NaN       NaN  nm3266654   Omer Pasha         NaN
# 143149            NaN       NaN  nm3266654   Omer Pasha         NaN
# 143428            NaN       NaN  nm3266654   Omer Pasha         NaN
# 143877            NaN       NaN  nm3266654   Omer Pasha         NaN
#
#         death_year
# 142004         NaN
# 142413         NaN
# 143149         NaN
# 143428         NaN
# 143877         NaN

# %%
xi = pd.Series(final_df['primary_name'].value_counts().head(20))

# %%
for i,k in xi.items():
    print(i,final_df[final_df['primary_name']==f'{i}'].isna().sum())
# Out:
# Larry Rosen start_year          0
# runtime_minutes     0
# genres              0
# averagerating      19
# numvotes           19
# primary_name        0
# death_year         53
# dtype: int64
# Rajiv Chilaka start_year          0
# runtime_minutes     0
# genres              0
# averagerating      37
# numvotes           37
# primary_name        0
# death_year         49
# dtype: int64
# Graeme Duane start_year          0
# runtime_minutes     0
# genres              0
# averagerating      31
# numvotes           31
# primary_name        0
# death_year         45
# dtype: int64
# Claudio Costa start_year          0
# runtime_minutes     0
# genres              0
# averagerating      41
# numvotes           41
# primary_name        0
# death_year         42
# dtype: int64
# Gérard Courant start_year          0
# runtime_minutes     0
# genres              0
# averagerating      41
# numvotes           41
# primary_name        0
# death_year         41
# dtype: int64
# Nayato Fio Nuala start_year          0
# runtime_minutes     0
# genres              0
# averagerating       4
# numvotes            4
# primary_name        0
# death_year         41
# dtype: int64
# Dustin Ferguson start_year          0
# runtime_minutes     0
# genres              0
# averagerating       8
# numvotes            8
# primary_name        0
# death_year         39
# dtype: int64
# Sergey A. start_year          0
# runtime_minutes     0
# genres              0
# averagerating       0
# numvotes            0
# primary_name        0
# death_year         39
# dtype: int64
# Jason Impey start_year          0
# runtime_minutes     0
# genres              0
# averagerating       7
# numvotes            7
# primary_name        0
# death_year         37
# dtype: int64
# Eckhart Schmidt start_year          0
# runtime_minutes     0
# genres              0
# averagerating      35
# numvotes           35
# primary_name        0
# death_year         37
# dtype: int64
# Tony Newton start_year          0
# runtime_minutes     0
# genres              0
# averagerating       8
# numvotes            8
# primary_name        0
# death_year         35
# dtype: int64
# Michael Fredianelli start_year          0
# runtime_minutes     0
# genres              0
# averagerating       4
# numvotes            4
# primary_name        0
# death_year         32
# dtype: int64
# Charlie Minn start_year          0
# runtime_minutes     0
# genres              0
# averagerating      10
# numvotes           10
# primary_name        0
# death_year         29
# dtype: int64
# Paul T.T. Easter start_year          0
# runtime_minutes     0
# genres              0
# averagerating       0
# numvotes            0
# primary_name        0
# death_year         28
# dtype: int64
# David DeCoteau start_year          0
# runtime_minutes     0
# genres              0
# averagerating       0
# numvotes            0
# primary_name        0
# death_year         27
# dtype: int64
# Sam Mason-Bell start_year          0
# runtime_minutes     0
# genres              0
# averagerating       4
# numvotes            4
# primary_name        0
# death_year         27
# dtype: int64
# Manny Velazquez start_year          0
# runtime_minutes     0
# genres              0
# averagerating      12
# numvotes           12
# primary_name        0
# death_year         27
# dtype: int64
# William Winckler start_year          0
# runtime_minutes     0
# genres              0
# averagerating       2
# numvotes            2
# primary_name        0
# death_year         27
# dtype: int64
# Philip Gardiner start_year          0
# runtime_minutes     0
# genres              0
# averagerating       8
# numvotes            8
# primary_name        0
# death_year         26
# dtype: int64
# Narinderpal Singh Chandok start_year          0
# runtime_minutes     0
# genres              0
# averagerating      26
# numvotes           26
# primary_name        0
# death_year         26
# dtype: int64

# %%
final_df1 = final_df

# %%
final_df1.drop(columns=['movie_id','primary_title','person_id','birth_year'],inplace=True)

# %%
final_df1
# Out:
#         start_year  runtime_minutes                      genres  \
# 8             2017        80.000000        Comedy,Drama,Fantasy
# 12            2018        75.000000                      Comedy
# 13            2017        86.721168             Horror,Thriller
# 14            2017        83.000000  Adventure,Animation,Comedy
# 16            2012        86.721168         Documentary,History
# ...            ...              ...                         ...
# 296891        2015        86.721168                 Documentary
# 296892        2015        86.721168                 Documentary
# 296895        2013        86.721168                      Comedy
# 296897        2013        86.721168                 Documentary
# 296898        2013        86.721168                 Documentary
#
#         averagerating  numvotes               primary_name  death_year
# 8                 6.5     119.0          Valeria Sarmiento         NaN
# 12                NaN       NaN               Frank Howson         NaN
# 13                4.1      32.0                   Mc Jones         NaN
# 14                8.1     263.0           Anthony Harrison         NaN
# 16                NaN       NaN  José Manuel Alves Pereira         NaN
# ...               ...       ...                        ...         ...
# 296891            NaN       NaN              Angela Gurgel         NaN
# 296892            NaN       NaN      Ana Célia de Oliveira         NaN
# 296895            NaN       NaN              Kanchan Nayak         NaN
# 296897            NaN       NaN              Angela Gurgel         NaN
# 296898            NaN       NaN     Vinicius Augusto Bozzo         NaN
#
# [158728 rows x 7 columns]

# %%
xii = pd.Series(final_df['primary_name'].value_counts().head(30))

# %%
for i,k in xii.items():
    print(i,final_df1[final_df1['primary_name']==f'{i}'].isna().sum()==0)
# Out:
# Larry Rosen start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Rajiv Chilaka start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Graeme Duane start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Claudio Costa start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Gérard Courant start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Nayato Fio Nuala start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Dustin Ferguson start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Sergey A. start_year          True
# runtime_minutes     True
# genres              True
# averagerating       True
# numvotes            True
# primary_name        True
# death_year         False
# dtype: bool
# Jason Impey start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Eckhart Schmidt start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Tony Newton start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Michael Fredianelli start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Charlie Minn start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Paul T.T. Easter start_year          True
# runtime_minutes     True
# genres              True
# averagerating       True
# numvotes            True
# primary_name        True
# death_year         False
# dtype: bool
# David DeCoteau start_year          True
# runtime_minutes     True
# genres              True
# averagerating       True
# numvotes            True
# primary_name        True
# death_year         False
# dtype: bool
# Sam Mason-Bell start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Manny Velazquez start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# William Winckler start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Philip Gardiner start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Narinderpal Singh Chandok start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Ram Gopal Varma start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Scout Tafoya start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Andrew Jones start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Mark Polonia start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# James Franco start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Joel Lamangan start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Rizal Mantovani start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Christopher Forbes start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Evan Tramel start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool
# Mickey Reece start_year          True
# runtime_minutes     True
# genres              True
# averagerating      False
# numvotes           False
# primary_name        True
# death_year         False
# dtype: bool

# %% [markdown]
# We shall pull samples for 3 directors, 3 with full ratings(Sergey A. , Paul T.T. Easter , David DeCoteau)

# %% [markdown]
# Using the above names we shall conduct hypothesis tests to establish whether these directors perfom significantly better at Alpha = 0.05
#
# Ho1 = 'Director performance is normal'
#
# Ha1 = 'Director perfomance is above average'

# %%
mu = final_df['averagerating'].mean()
std = final_df['averagerating'].std()
alpha = 0.05
print(mu, std)
# Out:
# 6.339985568620028 1.4759082630923703

# %% [markdown]
# 1. Sergey

# %%
#Sergey A. hypothesis 
sergey_a = final_df[final_df['primary_name']=='Sergey A.']

# %% [markdown]
# Ho1 = Sergey ratings are normal
#
# Ha1 = Sergey ratings are better

# %%
t_statistic, p_value = stats.ttest_1samp(a=sergey_a['averagerating'], popmean=6.33) 
print(t_statistic , p_value)
# Out:
# 7.134987766901874 1.616225344726199e-08

# %% [markdown]
# We reject the null. Based on the p-value generated we shall recommend working with Sergey

# %% [markdown]
# 2. Paul T.T. Easter

# %%
#Paul T.T. Easter hypothesis 
paul_t = final_df[final_df['primary_name']=='Paul T.T. Easter']

# %% [markdown]
# Ho2 = Paul T.T. Easter ratings are normal.
#
# Ha2 = Paul T.T. Easter ratings are better.

# %%
t_statistic, p_value = stats.ttest_1samp(a=paul_t['averagerating'], popmean=6.33) 
print(t_statistic , p_value)
# Out:
# -16.871460859285637 7.235729552707125e-16

# %% [markdown]
# We reject the null. Based on the p value, Paul perfoms better than the population

# %% [markdown]
# 3. David DeCoteau

# %%
david_decoteau = final_df[final_df['primary_name']=='David DeCoteau']

# %% [markdown]
# Ho3 = David DeCoteau ratings are normal
#
# Ha3 = David DeCoteau ratings are better

# %%
t_statistic, p_value = stats.ttest_1samp(a=david_decoteau['averagerating'], popmean=6.33) 
print(t_statistic , p_value)
# Out:
# -14.376144076855885 6.93459619144652e-14

# %% [markdown]
# We reject the null. David DeCoteau ratings are better.

# %% [markdown]
# # We shall do a pair wise test against our 3 directors to rank them in order of preference
