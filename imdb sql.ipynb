# %%
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect('im.db')

pd.read_sql("""SELECT *
            FROM sqlite_master""",conn)
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %% [markdown]
# # Let's view the various tables

# %% [markdown]
# Let's start with the movie_basics table

# %%
movie_basics = pd.read_sql("""
SELECT *
                            FROM movie_basics""",conn)
movie_basics.isna().sum()
# Out:
# movie_id               0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
#

# %% [markdown]
# The director's table

# %%
directors = pd.read_sql("""
SELECT *
                        FROM directors""",conn)
directors.isna().sum()
# Out:
# movie_id     0
# person_id    0
# dtype: int64

# %% [markdown]
# Known for table

# %%
known_for = pd.read_sql("""
SELECT * FROM known_for""",conn)
known_for.isna().sum()
# Out:
# person_id    0
# movie_id     0
# dtype: int64

# %% [markdown]
# Movie AKAs

# %%
movie_akas = pd.read_sql("""SELECT * FROM movie_akas""",conn)
movie_akas.isna().sum()
# Out:
# movie_id                  0
# ordering                  0
# title                     0
# region                53293
# language             289988
# types                163256
# attributes           316778
# is_original_title        25
# dtype: int64

# %% [markdown]
# Movie ratings

# %%
movie_ratings = pd.read_sql("""SELECT * FROM movie_ratings""",conn)
movie_ratings.isna().sum()
# Out:
# movie_id         0
# averagerating    0
# numvotes         0
# dtype: int64

# %% [markdown]
# Persons table

# %%
persons = pd.read_sql("""SELECT * FROM persons""",conn)
persons.isna().sum()
# Out:
# person_id                  0
# primary_name               0
# birth_year            523912
# death_year            599865
# primary_profession     51340
# dtype: int64

# %% [markdown]
# Principals table

# %%
principals = pd.read_sql("""SELECT * FROM principals""",conn)
principals.isna().sum()
# Out:
# movie_id           0
# ordering           0
# person_id          0
# category           0
# job           850502
# characters    634826
# dtype: int64

# %% [markdown]
# Writers table

# %%
writers = pd.read_sql("""SELECT * FROM writers""",conn)
writers.isna().sum()
# Out:
# movie_id     0
# person_id    0
# dtype: int64

# %%
pd.read_sql("""
SELECT *
            FROM movie_basics, movie_ratings 
            JOIN directors
            USING(movie_id)""",conn)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.read_sql("""
#       2 SELECT *
#       3             FROM movie_basics, movie_ratings
#       4             JOIN directors
#       5             USING(movie_id)""",conn)
#
# File c:\Users\DanielOgando\anaconda3\Lib\site-packages\pandas\io\sql.py:635, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     633 with pandasSQL_builder(con) as pandas_sql:
#     634     if isinstance(pandas_sql, SQLiteDatabase):
# --> 635         return pandas_sql.read_query(
#     636             sql,
#     637             index_col=index_col,
#     638             params=params,
#     639             coerce_float=coerce_float,
#     640             parse_dates=parse_dates,
#     641             chunksize=chunksize,
#     642             dtype_backend=dtype_backend,  # type: ignore[arg-type]
#     643             dtype=dtype,
#     644         )
#     646     try:
#     647         _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\DanielOgando\anaconda3\Lib\site-packages\pandas\io\sql.py:2281, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2270     return self._query_iterator(
#    2271         cursor,
#    2272         chunksize,
#    (...)
#    2278         dtype_backend=dtype_backend,
#    2279     )
#    2280 else:
# -> 2281     data = self._fetchall_as_list(cursor)
#    2282     cursor.close()
#    2284     frame = _wrap_result(
#    2285         data,
#    2286         columns,
#    (...)
#    2291         dtype_backend=dtype_backend,
#    2292     )
#
# File c:\Users\DanielOgando\anaconda3\Lib\site-packages\pandas\io\sql.py:2296, in SQLiteDatabase._fetchall_as_list(self, cur)
#    2295 def _fetchall_as_list(self, cur):
# -> 2296     result = cur.fetchall()
#    2297     if not isinstance(result, list):
#    2298         result = list(result)
#
# MemoryError:
